# %% [markdown]
# #Applied Data Science Capstone Week 3

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
# !wget -q -O 'List_of_postal_codes_of_Canada.html' https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
with open('List_of_postal_codes_of_Canada.html') as html_file:
    soup = BeautifulSoup(html_file,"lxml")

# %% [markdown]
# # My assumptions
# There is only a table tag in the wiki page.
# Text in table's cell is in &lt;td&gt;abc&lt;/td&gt; or &lt;td&gt;&lt;a&gt;abc&lt;/a&gt;&lt;/td&gt;.

# %%
table_tag = soup.table
first_row = table_tag.find('tr')
table_header=['PostalCode', 'Borough', 'Neighborhood']
table_values = []

not_assigned = 'Not assigned'
#11

def get_text_in_tag(tag):
    """
    get text in like <td>aaa</td> or <td><a>aaa</a></td> from argument tag.
    """
    if tag.string is not None:
        return tag.string
    else:
        return tag.find('a').string

# %% [markdown]
# Read the 2nd or later rows in table and create dictionary.<br/>
# When postalcode as key is in dictionary alaready, add Neighbourhood to array in value of dictionary.

# %%
postcode_dict = {} 
for tr in first_row.find_next_siblings():
    row = [ get_text_in_tag(td) if td.string is None else td.string.strip() for td in tr.find_all('td')]

    if row[1] == not_assigned:
        continue
    elif row[2] == not_assigned:
        postcode_dict.setdefault(row[0],  [row[1] ,[] ] )[1].append(row[1])
    else:
        postcode_dict.setdefault(row[0],  [row[1] ,[] ] )[1].append(row[2])
        
data_src = [ [key, value[0], ','.join(value[1]) ] for key,value in postcode_dict.items()]

# %% [markdown]
# Create DataFrame and show it.

# %%
df = pd.DataFrame(data_src, columns=table_header)

display(df)
# Out:
#     PostalCode           Borough  \
# 0          M5T  Downtown Toronto
# 1          M3N        North York
# 2          M3J        North York
# 3          M6M              York
# 4          M4A        North York
# 5          M5B  Downtown Toronto
# 6          M3H        North York
# 7          M4T   Central Toronto
# 8          M9L        North York
# 9          M1P       Scarborough
# 10         M4E      East Toronto
# 11         M2K        North York
# 12         M6B        North York
# 13         M5J  Downtown Toronto
# 14         M4C         East York
# 15         M5S  Downtown Toronto
# 16         M5R   Central Toronto
# 17         M4B         East York
# 18         M3M        North York
# 19         M7Y      East Toronto
# 20         M9V         Etobicoke
# 21         M1X       Scarborough
# 22         M3C        North York
# 23         M4Y  Downtown Toronto
# 24         M4L      East Toronto
# 25         M1L       Scarborough
# 26         M4V   Central Toronto
# 27         M5L  Downtown Toronto
# 28         M1E       Scarborough
# 29         M5C  Downtown Toronto
# ..         ...               ...
# 73         M6N              York
# 74         M1C       Scarborough
# 75         M2R        North York
# 76         M4P   Central Toronto
# 77         M6P      West Toronto
# 78         M5E  Downtown Toronto
# 79         M9A         Etobicoke
# 80         M2N        North York
# 81         M8Z         Etobicoke
# 82         M5N   Central Toronto
# 83         M4N   Central Toronto
# 84         M8V         Etobicoke
# 85         M4M      East Toronto
# 86         M6K      West Toronto
# 87         M1W       Scarborough
# 88         M4X  Downtown Toronto
# 89         M1G       Scarborough
# 90         M8X         Etobicoke
# 91         M5M        North York
# 92         M6H      West Toronto
# 93         M6L        North York
# 94         M9N              York
# 95         M5P   Central Toronto
# 96         M7A      Queen's Park
# 97         M6J      West Toronto
# 98         M1J       Scarborough
# 99         M2P        North York
# 100        M5X  Downtown Toronto
# 101        M6C              York
# 102        M1R       Scarborough
#
#                                           Neighborhood
# 0              Chinatown,Grange Park,Kensington Market
# 1                                  Downsview Northwest
# 2                       Northwood Park,York University
# 3          Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 4                                     Victoria Village
# 5                              Ryerson,Garden District
# 6        Bathurst Manor,Downsview North,Wilson Heights
# 7                           Moore Park,Summerhill East
# 8                                        Humber Summit
# 9    Dorset Park,Scarborough Town Centre,Wexford He...
# 10                                         The Beaches
# 11                                     Bayview Village
# 12                                           Glencairn
# 13     Harbourfront East,Toronto Islands,Union Station
# 14                                    Woodbine Heights
# 15                       Harbord,University of Toronto
# 16                   The Annex,North Midtown,Yorkville
# 17                      Woodbine Gardens,Parkview Hill
# 18                                   Downsview Central
# 19    Business reply mail Processing Centre969 Eastern
# 20   Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 21                                         Upper Rouge
# 22                     Flemingdon Park,Don Mills South
# 23                                Church and Wellesley
# 24                       The Beaches West,India Bazaar
# 25                       Clairlea,Golden Mile,Oakridge
# 26   Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 27                       Commerce Court,Victoria Hotel
# 28                     Guildwood,Morningside,West Hill
# 29                                      St. James Town
# ..                                                 ...
# 73                        The Junction North,Runnymede
# 74                Highland Creek,Rouge Hill,Port Union
# 75                                     Willowdale West
# 76                                    Davisville North
# 77                        High Park,The Junction South
# 78                                         Berczy Park
# 79                                    Islington Avenue
# 80                                    Willowdale South
# 81   Kingsway Park South West,Mimico NW,The Queensw...
# 82                                            Roselawn
# 83                                       Lawrence Park
# 84          Humber Bay Shores,Mimico South,New Toronto
# 85                                     Studio District
# 86          Brockton,Exhibition Place,Parkdale Village
# 87                        L'Amoreaux West,Steeles West
# 88                          Cabbagetown,St. James Town
# 89                                              Woburn
# 90         The Kingsway,Montgomery Road,Old Mill North
# 91                    Bedford Park,Lawrence Manor East
# 92                         Dovercourt Village,Dufferin
# 93              Maple Leaf Park,North Park,Upwood Park
# 94                                              Weston
# 95                  Forest Hill North,Forest Hill West
# 96                                        Queen's Park
# 97                             Little Portugal,Trinity
# 98                                 Scarborough Village
# 99                                     York Mills West
# 100              First Canadian Place,Underground city
# 101                                 Humewood-Cedarvale
# 102                                   Maryvale,Wexford
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# end
