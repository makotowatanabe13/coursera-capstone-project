# %% [markdown]
# #Applied Data Science Capstone Week 3

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
# !wget -q -O 'List_of_postal_codes_of_Canada.html' https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
with open('List_of_postal_codes_of_Canada.html') as html_file:
    soup = BeautifulSoup(html_file,"lxml")

# %% [markdown]
# # My assumptions
# There is only a table tag in the wiki page.
# Text in table's cell is in &lt;td&gt;abc&lt;/td&gt; or &lt;td&gt;&lt;a&gt;abc&lt;/a&gt;&lt;/td&gt;.

# %%
table_tag = soup.table
first_row = table_tag.find('tr')
table_header=[ th.string for th in first_row.find_all('th')]
table_values = ['PostalCode', 'Borough', 'Neighborhood']

not_assigned = 'Not assigned'
#11

def get_text_in_tag(tag):
    """
    get text in like <td>aaa</td> or <td><a>aaa</a></td> from argument tag.
    """
    if tag.string is not None:
        return tag.string
    else:
        return tag.find('a').string

# %% [markdown]
# Read the 2nd or later rows in table and create dictionary.<br/>
# When postalcode as key is in dictionary alaready, add Neighbourhood to array in value of dictionary.

# %%
postcode_dict = {} 
for tr in first_row.find_next_siblings():
    row = [ get_text_in_tag(td) if td.string is None else td.string.strip() for td in tr.find_all('td')]

    if row[1] == not_assigned:
        continue
    elif row[2] == not_assigned:
        postcode_dict.setdefault(row[0],  [row[1] ,[] ] )[1].append(row[1])
    else:
        postcode_dict.setdefault(row[0],  [row[1] ,[] ] )[1].append(row[2])
        
data_src = [ [key, value[0], ','.join(value[1]) ] for key,value in postcode_dict.items()]

# %% [markdown]
# Create DataFrame and show it.

# %%
df = pd.DataFrame(data_src, columns=table_header)

display(df)
# Out:
#     Postcode           Borough  \
# 0        M1V       Scarborough
# 1        M9C         Etobicoke
# 2        M9W         Etobicoke
# 3        M5R   Central Toronto
# 4        M8Y         Etobicoke
# 5        M9R         Etobicoke
# 6        M6N              York
# 7        M4Y  Downtown Toronto
# 8        M8X         Etobicoke
# 9        M6C              York
# 10       M6M              York
# 11       M6S      West Toronto
# 12       M5T  Downtown Toronto
# 13       M4J         East York
# 14       M5W  Downtown Toronto
# 15       M9A         Etobicoke
# 16       M5L  Downtown Toronto
# 17       M5J  Downtown Toronto
# 18       M6H      West Toronto
# 19       M5K  Downtown Toronto
# 20       M4V   Central Toronto
# 21       M4E      East Toronto
# 22       M2N        North York
# 23       M4H         East York
# 24       M4X  Downtown Toronto
# 25       M4P   Central Toronto
# 26       M6J      West Toronto
# 27       M1S       Scarborough
# 28       M4N   Central Toronto
# 29       M5H  Downtown Toronto
# ..       ...               ...
# 73       M1C       Scarborough
# 74       M5N   Central Toronto
# 75       M5E  Downtown Toronto
# 76       M6L        North York
# 77       M5B  Downtown Toronto
# 78       M9P         Etobicoke
# 79       M3A        North York
# 80       M6P      West Toronto
# 81       M9N              York
# 82       M4S   Central Toronto
# 83       M5M        North York
# 84       M4B         East York
# 85       M1G       Scarborough
# 86       M8Z         Etobicoke
# 87       M3L        North York
# 88       M2K        North York
# 89       M1E       Scarborough
# 90       M2P        North York
# 91       M5P   Central Toronto
# 92       M3J        North York
# 93       M4R   Central Toronto
# 94       M4A        North York
# 95       M6A        North York
# 96       M1T       Scarborough
# 97       M2H        North York
# 98       M6K      West Toronto
# 99       M5A  Downtown Toronto
# 100      M1W       Scarborough
# 101      M9L        North York
# 102      M6R      West Toronto
#
#                                         Neighbourhood
#
# 0    Agincourt North,L'Amoreaux East,Milliken,Steel...
# 1    Bloordale Gardens,Eringate,Markland Wood,Old B...
# 2                                            Northwest
# 3                    The Annex,North Midtown,Yorkville
# 4    Humber Bay,King's Mill Park,Kingsway Park Sout...
# 5    Kingsview Village,Martin Grove Gardens,Richvie...
# 6                         The Junction North,Runnymede
# 7                                 Church and Wellesley
# 8          The Kingsway,Montgomery Road,Old Mill North
# 9                                   Humewood-Cedarvale
# 10         Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 11                                   Runnymede,Swansea
# 12             Chinatown,Grange Park,Kensington Market
# 13                                        East Toronto
# 14                     Stn A PO Boxes 25 The Esplanade
# 15                                    Islington Avenue
# 16                       Commerce Court,Victoria Hotel
# 17     Harbourfront East,Toronto Islands,Union Station
# 18                         Dovercourt Village,Dufferin
# 19             Design Exchange,Toronto Dominion Centre
# 20   Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 21                                         The Beaches
# 22                                    Willowdale South
# 23                                    Thorncliffe Park
# 24                          Cabbagetown,St. James Town
# 25                                    Davisville North
# 26                             Little Portugal,Trinity
# 27                                           Agincourt
# 28                                       Lawrence Park
# 29                              Adelaide,King,Richmond
# ..                                                 ...
# 73                Highland Creek,Rouge Hill,Port Union
# 74                                            Roselawn
# 75                                         Berczy Park
# 76              Maple Leaf Park,North Park,Upwood Park
# 77                             Ryerson,Garden District
# 78                                           Westmount
# 79                                           Parkwoods
# 80                        High Park,The Junction South
# 81                                              Weston
# 82                                          Davisville
# 83                    Bedford Park,Lawrence Manor East
# 84                      Woodbine Gardens,Parkview Hill
# 85                                              Woburn
# 86   Kingsway Park South West,Mimico NW,The Queensw...
# 87                                      Downsview West
# 88                                     Bayview Village
# 89                     Guildwood,Morningside,West Hill
# 90                                     York Mills West
# 91                  Forest Hill North,Forest Hill West
# 92                      Northwood Park,York University
# 93                                  North Toronto West
# 94                                    Victoria Village
# 95                     Lawrence Heights,Lawrence Manor
# 96               Clarks Corners,Sullivan,Tam O'Shanter
# 97                                   Hillcrest Village
# 98          Brockton,Exhibition Place,Parkdale Village
# 99                            Harbourfront,Regent Park
# 100                       L'Amoreaux West,Steeles West
# 101                                      Humber Summit
# 102                              Parkdale,Roncesvalles
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# end
